# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
df= pd.read_csv('adult.csv')
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10),dpi=100)
plt.scatter(x=df['age'],y=df['hours.per.week'])
plt.show()

# %% [markdown]
# Observation : There is no relation between age and number of hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8),dpi=100)
sns.lineplot(data=df,x='education.num',y='capital.gain')
plt.show()

# %% [raw]
# Observation : There is no relation between the capital gain amount for different educational qualifications

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10),dpi=100)
plt.scatter(y=df['capital.gain'],x=df['hours.per.week'])
plt.xlabel('Working hours per week')
plt.ylabel('Capital Gain')
plt.show()

# %%
df[(df['hours.per.week']==80) & (df['capital.gain']==0)].head()
# Out:
#       age         workclass  fnlwgt    education  education.num  \
# 81     60      Self-emp-inc  336188  Prof-school             15
# 96     46  Self-emp-not-inc  198759  Prof-school             15
# 354    35           Private  199352  Prof-school             15
# 559    42  Self-emp-not-inc  157562    Bachelors             13
# 1060   35         Local-gov  668319    Bachelors             13
#
#           marital.status       occupation relationship   race   sex  \
# 81    Married-civ-spouse   Prof-specialty      Husband  White  Male
# 96    Married-civ-spouse   Prof-specialty      Husband  White  Male
# 354   Married-civ-spouse   Prof-specialty      Husband  White  Male
# 559   Married-civ-spouse  Farming-fishing      Husband  White  Male
# 1060  Married-civ-spouse  Exec-managerial      Husband  White  Male
#
#       capital.gain  capital.loss  hours.per.week native.country income
# 81               0          2415              80  United-States   >50K
# ...

# %%
Observation : Ther is no relation.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
pd.pivot_table(df,values='hours.per.week',index='age',aggfunc='mean').plot(kind='line')
plt.show()

# %%
Observation : The number of working hours increases from age 18 to 30 then it remains constant till the age of 60 and the goes dowm

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=df,x=df['age'],y=df['capital.loss'])
plt.grid()
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='age',y='capital.gain')
plt.show()

# %%
No,  there is no relation between capital gain and age

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.income.value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
pd.pivot_table(df,index='income',values='age',aggfunc='mean').plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %%
df['age'].groupby(by=df['income']).mean().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=df,x='sex',y='hours.per.week')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,7))
df.groupby(by=df['education'])['capital.gain'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,7))
df.groupby(by=df['sex'])['age'].mean().plot(kind='bar',color=['cyan','gold'])
plt.xticks(rotation=0)
plt.show()

# %% [raw]
# Observation: Average age of male is more than that of female.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df,x='income',y='hours.per.week')
plt.show()

# %% [raw]
# Observation: Though the median for both income classes is almost same and aroud 40 hours per week, the observations after median in income class of more than 50k tend to have more working hours which is not the seen in subsequent class.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df,y='age',x='race',hue='sex',split=True)
plt.show()

# %%
df.age[(df.race=='Asian-Pac-Islaner race') & (df.sex=='Female')].skew()
# Out:
# nan

# %%
df.age[(df.race=='White') & (df.sex=='Female')].mean()
# Out:
# 36.811617681092336

# %%
df.age[(df.race=='White') & (df.sex=='Female')].median()
# Out:
# 35.0

# %%
df.age[(df.race=='Black') & (df.sex=='Male')].skew()
# Out:
# 0.5509846332118986

# %% [raw]
# if we calculate, ecept for asian pac islander all are positively skewed

# %% [raw]
# Observations: Positively Skewed distributions of age based on the gender and race of the individual
# 1.White Male
# 2.White Female
# 3. Other Male
# 4. Other Female
# 5. Amer-Indian_Eskimo

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df,x='workclass',y='hours.per.week')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(10,7))
df.groupby(by=df['workclass'])['hours.per.week'].mean().plot(kind='bar',color=['cyan','gold'])
plt.xticks(rotation=30)
plt.show()

# %%
Observation: Working hours for self-emp-inc is most among all other classes.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df,x='sex',y='fnlwgt')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(10,7))
df.groupby(by=df['sex'])['fnlwgt'].mean().plot(kind='bar',color=['cyan','gold'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df2=pd.crosstab(index=df['sex'],columns=df['income']).apply(lambda x : x/x.sum(),axis=1)
df2.plot(kind='bar',stacked=True)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(index=df['income'],columns=df['sex']).plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df2=pd.crosstab(index=df['sex'],columns=df['occupation'])
df2
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# sex
# Female       841          2537             0           222             1159
# Male        1002          1233             9          3877             2907
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# sex
# Female                   65                164                550
# Male                    929               1206               1452
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# sex
# Female               1800              141            1515               76
# Male                 1495                8            2625              573
#
# occupation  Sales  Tech-support  Transport-moving
# sex
# Female       1263           348                90
# Male         2387           580              1507

# %% [raw]
# Observation : Yes. Armed Forces

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(index=df['income'],columns=df['workclass']).plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(index=df['income'],columns=df['marital.status']).plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(index=df['income'],columns=df['occupation']).plot(kind='bar')
plt.xticks(rotation=0)
plt.show()
